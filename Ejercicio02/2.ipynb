-- %%
cuadrados :: [Int]
cuadrados = [x^2 | x <- [1..10]]

divPor3 :: [Int]
divPor3 = [x | x <- [1..30], x `mod` 3 == 0]

pares :: [(Int, Int)]
pares = [(x, y) | x <- [1..5], y <- [1..5], x < y]

-- %%
print cuadrados
-- Out:
-- [1,4,9,16,25,36,49,64,81,100]

-- %%
divisores :: Int -> [Int]
divisores n = [x | x <- [1..n], n `mod` x == 0]

-- %%
print divisores
-- Out:
-- <interactive>:1:1: error: [GHC-39999]
--     • No instance for ‘Show (Int -> [Int])’ arising from a use of ‘print’
--         (maybe you haven't applied a function to enough arguments?)
--     • In the expression: print divisores
--       In an equation for ‘it’: it = print divisores

-- %%
divisoresPropios :: Int -> [Int]
divisoresPropios n = [x | x <- [1..n-1], n `mod` x == 0]

esPerfecto :: Int -> Bool
esPerfecto n = sum (divisoresPropios n) == n
